# %%
import random
import tabulate

# %%
def new_game():
  l=[i for i in range(1,26)]
  random.shuffle(l)
  return l                            #for new game need to initalize l again

# %%
def display(l):
  a=[l[i:i+5] for i in range(0,25,5)]
  print(tabulate.tabulate(a,tablefmt='fancy_grid'))         # ithu display panna

# %%
# ithu num check panni game continue panna
def bingo(l):
  num=0
  while (num<26):
    num=int(input("Enter the number: "))
    for i in range(0,len(l)):
      if l[i]==num:
        l[i]=0
      elif l[i]==0:
        continue
      else:
        continue
      display(l)
      w=check_win(l)
      if w == 5:
        print("You won!")
        return 0
      print("Computer's turn: ")
      b=random.choice(l)
      print(b)
      for i in range (len(l)):
        while b==0:
          b=random.choice(l)
          print(b)
        if b==l[i]:
          l[i]=0
          break
      display(l)
      w=check_win(l)
      if w == 5:
        print("Computer won!")
        return 0

# %%
def check_win(l):
    a = [l[i:i+5] for i in range(0, 25, 5)]
    zero_rows = 0
    zero_cols = 0
    # Check rows
    for row in a:
        if all(x == 0 for x in row):
            zero_rows += 1
    # Check columns
    for col in range(5):
        if all(a[row][col] == 0 for row in range(5)):
            zero_cols +=1
    return zero_rows + zero_cols

# %%
# MAIN PART
print("----------------------------------------------BINGO--------------------------------------------")
print("RULES:\n\t\t1.The goal is to be the first to get the score of 5.\n\t\t2.To start the game press 'n'\n\t\t3.To resume an old game press'c'\n\t\t4.To quit enter number greater than 25.\n\t\t5.To continue giving the input enter values between 1-25.")
print(" To start a new game press 'n' to continue old game press 'c'")
ch=input("Enter your choice: ")
if ch=='n':
  l=new_game()
  display(l)
  bingo(l)
elif ch=='c':
  display(l)
  bingo(l)
else:
  print("Thank you for ur time :)")
# Out:
# ----------------------------------------------BINGO--------------------------------------------
# RULES:
# 		1.The goal is to be the first to get the score of 5.
# 		2.To start the game press 'n'
# 		3.To resume an old game press'c'
# 		4.To quit enter number greater than 25.
# 		5.To continue giving the input enter values between 1-25.
#  To start a new game press 'n' to continue old game press 'c'
# Enter your choice: n
# ╒════╤════╤════╤════╤════╕
# │  4 │  1 │ 25 │  7 │ 17 │
# ├────┼────┼────┼────┼────┤
# │  5 │ 13 │ 14 │ 20 │ 23 │
# ├────┼────┼────┼────┼────┤
# │ 22 │ 18 │ 10 │ 16 │ 11 │
# ├────┼────┼────┼────┼────┤
# │ 15 │ 24 │ 19 │ 12 │  8 │
# ├────┼────┼────┼────┼────┤
# │  3 │  6 │  2 │ 21 │  9 │
# ╘════╧════╧════╧════╧════╛
# Enter the number: 16
# ╒════╤════╤════╤════╤════╕
# │  4 │  1 │ 25 │  7 │ 17 │
# ├────┼────┼────┼────┼────┤
# │  5 │ 13 │ 14 │ 20 │ 23 │
# ├────┼────┼────┼────┼────┤
# │ 22 │ 18 │ 10 │  0 │ 11 │
# ├────┼────┼────┼────┼────┤
# │ 15 │ 24 │ 19 │ 12 │  8 │
# ├────┼────┼────┼────┼────┤
# │  3 │  6 │  2 │ 21 │  9 │
# ╘════╧════╧════╧════╧════╛
# Computer's turn:
# 13
# ╒════╤════╤════╤════╤════╕
# │  4 │  1 │ 25 │  7 │ 17 │
# ├────┼────┼────┼────┼────┤
# │  5 │  0 │ 14 │ 20 │ 23 │
# ├────┼────┼────┼────┼────┤
# │ 22 │ 18 │ 10 │  0 │ 11 │
# ├────┼────┼────┼────┼────┤
